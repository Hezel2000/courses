# %% [markdown]
# # Basics- Plotting selected data

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/Banda Arc.csv')

data = df.loc[3:9, ['MGO(WT%)', 'SIO2(WT%)', 'MNO(WT%)']]

el1 = 'MGO(WT%)'

plt.scatter(data[el1], data['MNO(WT%)'])
plt.xlabel(el1)
# Out:
# Text(0.5, 0, 'MGO(WT%)')
