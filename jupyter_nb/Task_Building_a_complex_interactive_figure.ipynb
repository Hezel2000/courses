# %% [markdown]
# # Building a complex, interactive figure

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import modules.mineralogyModule as mm
from ipywidgets import interact

# %%
world_data = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world_data.plot(color = 'lightgreen', edgecolor = 'black', linewidth = .3)
# Out:
# <AxesSubplot:>

# %%
def readfile(file):
    df = pd.read_csv('data/georoc data/Bastar Craton.csv')
    dfGeo = gpd.GeoDataFrame(df, geometry = gpd.points_from_xy(df['Longitude (Min)'], df['Latitude (Min)']))
    return dfGeo

# %%
axis = world_data.plot(color = 'lightgreen', edgecolor = 'black', linewidth = .3)
dfGeo.plot(ax = axis)
dfGeo2.plot(ax = axis)
# Out:
# <AxesSubplot:>

# %%
fig = plt.figure()
fig.set_figheight(10)
fig.set_figwidth(10)

ax1 = plt.subplot2grid(shape = (3, 3), loc = (0, 0), colspan = 2)

ax3 = plt.subplot2grid(shape = (3, 3), loc = (1, 0), colspan = 1)
ax4 = plt.subplot2grid(shape = (3, 3), loc = (1, 1), colspan = 1)

ax1.scatter([1,2,3], [4,5,6])

ax3.scatter([1,2,3], [4,5,6])
ax4.scatter([1,2,3], [4,5,6])
